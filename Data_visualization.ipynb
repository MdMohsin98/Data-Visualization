# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.plot(x,y, color = 'red')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.scatter(x,y)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.scatter(x,y, color = 'orange')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.barbs(x,y)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.quiver(x,y)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.plot(x,y, color = 'blue', linewidth = 4, linestyle = 'dotted')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.plot(x,y, color = 'blue', linewidth = 4, linestyle = 'dashdot')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, color = 'blue', linewidth = 4, linestyle = 'solid')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, 'g-+')

# %%
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, 'rD-.')

# %%
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, color = 'red', linestyle = '-.', marker = 'D', markersize = 10)

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, color = 'red', linestyle = '', marker = '+', markersize = 20)

# %%
# Alpha control the transparancy : Alpha Function
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, color = 'red', alpha = 1, animated = 100)

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, color = 'red', linestyle = 'b+--', markersize = 10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <module>
#       2 plt.ylabel('Temperature')
#       3 plt.title('Weather')
# ----> 4 plt.plot(x,y, color = 'red', linestyle = 'b+--', markersize = 10)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
# ...

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(x,y,'r+--')

# %%
plt.plot(x,y,color='blue',marker='H',linestyle='', markersize = 20)

# %%
plt.plot(x,y,color='blue',marker='^',linestyle='-.', markersize = 20)

# %%
plt.plot(x,y,color='blue',marker='v',linestyle='', markersize = 20)

# %%
plt.plot(x,y,color='blue',marker='h',linestyle='', markersize = 20)

# %%
plt.plot(x,y,color='blue',marker='^',linestyle='--', markersize = 20, alpha = 0.1)

# %%
plt.plot(x,y,color='black',marker='d',linestyle='', markersize = 20, alpha = 0.1)

# %%
plt.plot(x,y,color='black',marker='d',linestyle='', markersize = 20, alpha = 0.5)
