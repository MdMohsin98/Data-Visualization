# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
a = pd.read_csv("C:\\Users\\Dell\\PycharmProjects\\coding\\venv\\Train.csv")
a
# Out:
#        row_id  user_id  category_id  video_id  age  gender  \
# 0           1    19990           37       128   24    Male
# 1           2     5304           32       132   14  Female
# 2           3     1840           12        24   19    Male
# 3           4    12597           23       112   19    Male
# 4           5    13626           23       112   27    Male
# ...       ...      ...          ...       ...  ...     ...
# 89192   89193    23996           15        32   25    Male
# 89193   89194    20466           20        47   31    Male
# 89194   89195    13655           16        97   25    Male
# 89195   89196    24840            9        18   35    Male
# 89196   89197    27183           25       150   13    Male
#
#                  profession  followers  views  engagement_score
# 0                   Student        180   1000              4.33
# 1                   Student        330    714              1.79
# ...

# %%
a.head()
# Out:
#    row_id  user_id  category_id  video_id  age  gender            profession  \
# 0       1    19990           37       128   24    Male               Student
# 1       2     5304           32       132   14  Female               Student
# 2       3     1840           12        24   19    Male               Student
# 3       4    12597           23       112   19    Male               Student
# 4       5    13626           23       112   27    Male  Working Professional
#
#    followers  views  engagement_score
# 0        180   1000              4.33
# 1        330    714              1.79
# 2        180    138              4.35
# 3        220    613              3.77
# 4        220    613              3.13

# %%
a.describe()
# Out:
#              row_id       user_id   category_id      video_id           age  \
# count  89197.000000  89197.000000  89197.000000  89197.000000  89197.000000
# mean   44599.000000  13881.909806     18.323733     77.715383     24.848616
# std    25749.100318   8005.582771     11.675154     48.469656      8.955535
# min        1.000000      1.000000      1.000000      1.000000     10.000000
# 25%    22300.000000   6945.000000      8.000000     34.000000     18.000000
# 50%    44599.000000  13892.000000     16.000000     76.000000     23.000000
# 75%    66898.000000  20819.000000     26.000000    120.000000     32.000000
# max    89197.000000  27734.000000     47.000000    175.000000     68.000000
#
#           followers         views  engagement_score
# count  89197.000000  89197.000000      89197.000000
# mean     252.460172    502.980268          3.487797
# std       46.094468    268.569482          0.863498
# min      160.000000     30.000000          0.000000
# ...

# %%
sn.barplot(x = a.profession, y = a.views)
# Out:
# <AxesSubplot:xlabel='profession', ylabel='views'>

# %%
k = a.groupby('gender')
for b, c in k:
    print(b)
    print(c)
# Out:
# Female
#        row_id  user_id  category_id  video_id  age  gender  \
# 1           2     5304           32       132   14  Female
# 10         11    15545           12        88   18  Female
# 12         13     7626            5        72   36  Female
# 18         19     3908           30        83   33  Female
# 21         22     5795           31       151   25  Female
# ...       ...      ...          ...       ...  ...     ...
# 89177   89178    24242            4         7   45  Female
# 89183   89184     1198            1         2   33  Female
# 89185   89186    27416           31       152   36  Female
# 89188   89189    10412           12        42   18  Female
# 89190   89191    19181           34       114   14  Female
#
#                  profession  followers  views  engagement_score
# 1                   Student        330    714              1.79
# 10                  Student        180    138              3.73
# ...

# %%
a1 = k.get_group('Male')
sn.distplot(a1.followers)
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='followers', ylabel='Density'>
