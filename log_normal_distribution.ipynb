# %%
import pandas as pd
import seaborn as sns
import numpy as np
df = pd.read_csv("C:\\Users\\Dell\\PycharmProjects\\coding\\venv\\data_set1.csv", 
    index_col=None, 
    names=["price","numbers"], 
    skiprows=1
)
df.head()
# Out:
#    price  numbers
# 0    149        1
# 1    225        1
# 2    150        3
# 3     89        1
# 4     80       10

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
g = sns.barplot(x='price',y='numbers',data=df)
g.set_xticklabels(g.get_xticklabels(), 
                          rotation=45, 
                          horizontalalignment='right');4
# Out:
# 4
